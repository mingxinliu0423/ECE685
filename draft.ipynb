# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.get_arch_list())
# Out:
# 2.8.0.dev20250620+cu128
# 12.8
# ['sm_61', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']
